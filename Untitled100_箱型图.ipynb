# %% [markdown]
# <a href="https://colab.research.google.com/github/li199959/one/blob/main/Untitled100_%E7%AE%B1%E5%9E%8B%E5%9B%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加载数据
file_path = '/content/processed_data.xlsx'  # 请确保这是您的Excel文件路径
df = pd.read_excel(file_path, sheet_name=0)

# 提供的颜色组合
colors = ["#F8766D", "#7CAE00", "#00BFC4", "#C77CFF"]

# 设置箱体宽度变量
box_width = 0.4

# 创建箱线图
plt.figure(figsize=(5, 6))
for idx, col in enumerate(df.columns):
    plt.boxplot(df[col], positions=[idx + 1], widths=box_width, patch_artist=True,
                boxprops=dict(facecolor=colors[idx], edgecolor='black', linewidth=1))

# 设置x轴标签，移除x轴刻度，调整y轴位置，并设置y轴标签
# 修改：旋转x轴标签45°，增加字体大小和粗细，并将x轴标签靠近x轴
plt.xticks(range(1, len(df.columns) + 1), df.columns, rotation=45, fontsize=20,verticalalignment='top')
# 修改：移除x轴刻度
plt.tick_params(axis='x', length=0)
plt.tick_params(axis='y', direction='out', length=6, labelsize=18)
plt.ylabel('Fct(s)', fontsize=25)

# 在整个图形周围添加边框
plt.gca().add_patch(plt.Rectangle((-0.5, plt.gca().get_ylim()[0]), len(df.columns) + 1,
                                  plt.gca().get_ylim()[1] - plt.gca().get_ylim()[0],
                                  fill=None, edgecolor='black', linewidth=1.2))

# 显示没有网格线和标题的图形
plt.grid(False)
plt.tight_layout()

plt.savefig('output_image.png', dpi=1000)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加载数据
file_path = '/content/all2all.xlsx'  # 请确保这是您的Excel文件路径
df = pd.read_excel(file_path, sheet_name=0)

# 提供的颜色组合
colors = ["#F8766D", "#7CAE00", "#00BFC4", "#C77CFF"]

# 设置箱体宽度变量
box_width = 0.4

# 创建箱线图
plt.figure(figsize=(5, 6))
for idx, col in enumerate(df.columns):
    plt.boxplot(df[col], positions=[idx + 1], widths=box_width, patch_artist=True,
                boxprops=dict(facecolor=colors[idx], edgecolor='black', linewidth=1))

# 设置x轴标签，移除x轴刻度，调整y轴位置，并设置y轴标签
# 修改：旋转x轴标签45°，增加字体大小和粗细，并将x轴标签靠近x轴
plt.xticks(range(1, len(df.columns) + 1), df.columns, rotation=45, fontsize=20,verticalalignment='top')
# 修改：移除x轴刻度
plt.tick_params(axis='x', length=0)
plt.tick_params(axis='y', direction='out', length=6, labelsize=18)
plt.ylabel('Fct(s)', fontsize=25)

# 在整个图形周围添加边框
plt.gca().add_patch(plt.Rectangle((-0.5, plt.gca().get_ylim()[0]), len(df.columns) + 1,
                                  plt.gca().get_ylim()[1] - plt.gca().get_ylim()[0],
                                  fill=None, edgecolor='black', linewidth=1.2))

# 显示没有网格线和标题的图形
plt.grid(False)
plt.tight_layout()


plt.savefig('output_image2.png', dpi=1000)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加载数据
file_path = '/content/all2all.xlsx'  # 请确保这是您的Excel文件路径
df = pd.read_excel(file_path, sheet_name=0)

# 提供的颜色组合
colors = ["#F8766D", "#7CAE00", "#00BFC4", "#C77CFF"]

# 修改中位数线的颜色
medianprops = dict(color='black', linewidth=1.5)

# 设置箱体宽度变量
box_width = 0.4

# 创建箱线图
plt.figure(figsize=(5, 6))
for idx, col in enumerate(df.columns):
    plt.boxplot(df[col], positions=[idx + 1], widths=box_width, patch_artist=True,
                boxprops=dict(facecolor=colors[idx], edgecolor='black', linewidth=1),
                medianprops=medianprops)

# 设置x轴标签，移除x轴刻度，调整y轴位置，并设置y轴标签
plt.xticks(range(1, len(df.columns) + 1), df.columns, rotation=45, fontsize=20, verticalalignment='top')
plt.tick_params(axis='x', length=0)
plt.tick_params(axis='y', direction='out', length=6, labelsize=18)
plt.ylabel('Fct(s)', fontsize=25)

# 在整个图形周围添加边框
plt.gca().add_patch(plt.Rectangle((-0.5, plt.gca().get_ylim()[0]), len(df.columns) + 1,
                                  plt.gca().get_ylim()[1] - plt.gca().get_ylim()[0],
                                  fill=None, edgecolor='black', linewidth=1.2))

# 显示没有网格线和标题的图形
plt.grid(False)
plt.tight_layout()

plt.savefig('output_image2_modified.png', dpi=1000)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加载数据
file_path = '/content/processed_data.xlsx'  # 请确保这是您的Excel文件路径
df = pd.read_excel(file_path, sheet_name=0)

# 提供的颜色组合
colors = ["#F8766D", "#7CAE00", "#00BFC4", "#C77CFF"]

# 修改中位数线的颜色
medianprops = dict(color='black', linewidth=1.5)

# 设置箱体宽度变量
box_width = 0.4

# 创建箱线图
plt.figure(figsize=(5, 6))
for idx, col in enumerate(df.columns):
    plt.boxplot(df[col], positions=[idx + 1], widths=box_width, patch_artist=True,
                boxprops=dict(facecolor=colors[idx], edgecolor='black', linewidth=1),
                medianprops=medianprops)

# 设置x轴标签，移除x轴刻度，调整y轴位置，并设置y轴标签
plt.xticks(range(1, len(df.columns) + 1), df.columns, rotation=45, fontsize=20, verticalalignment='top')
plt.tick_params(axis='x', length=0)
plt.tick_params(axis='y', direction='out', length=6, labelsize=18)
plt.ylabel('Fct(s)', fontsize=25)

# 在整个图形周围添加边框
plt.gca().add_patch(plt.Rectangle((-0.5, plt.gca().get_ylim()[0]), len(df.columns) + 1,
                                  plt.gca().get_ylim()[1] - plt.gca().get_ylim()[0],
                                  fill=None, edgecolor='black', linewidth=1.2))

# 显示没有网格线和标题的图形
plt.grid(False)
plt.tight_layout()

plt.savefig('output_image1_modified.png', dpi=1000)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加载数据
file_path = '/content/all2all.xlsx'  # 请确保这是您的Excel文件路径
df = pd.read_excel(file_path, sheet_name=0)

# 提供的颜色组合
colors = ["#F8766D", "#7CAE00", "#00BFC4", "#C77CFF"]

# 修改中位数线的颜色
medianprops = dict(color='black', linewidth=1.5)

# 设置箱体宽度变量
box_width = 0.4

# 创建箱线图
plt.figure(figsize=(5, 6))
for idx, col in enumerate(df.columns):
    plt.boxplot(df[col], positions=[idx + 1], widths=box_width, patch_artist=True,
                boxprops=dict(facecolor=colors[idx], edgecolor='black', linewidth=1),
                medianprops=medianprops)

# 设置x轴标签，移除x轴刻度，调整y轴位置，并设置y轴标签
plt.xticks(range(1, len(df.columns) + 1), df.columns, rotation=45, fontsize=20, verticalalignment='top')
plt.tick_params(axis='x', length=0, pad=-1)  # 设置x轴标题与x轴之间的距离
plt.tick_params(axis='y', direction='out', length=6, labelsize=18)
plt.ylabel('Fct(s)', fontsize=25)

# 在整个图形周围添加边框
plt.gca().add_patch(plt.Rectangle((-0.5, plt.gca().get_ylim()[0]), len(df.columns) + 1,
                                  plt.gca().get_ylim()[1] - plt.gca().get_ylim()[0],
                                  fill=None, edgecolor='black', linewidth=1.2))

# 显示没有网格线和标题的图形
plt.grid(False)
plt.tight_layout()

plt.savefig('all2all.png', dpi=1000)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加载数据
file_path = '/content/processed_data.xlsx'  # 请确保这是您的Excel文件路径
df = pd.read_excel(file_path, sheet_name=0)

# 提供的颜色组合
colors = ["#F8766D", "#7CAE00", "#00BFC4", "#C77CFF"]

# 修改中位数线的颜色
medianprops = dict(color='black', linewidth=1.5)

# 设置箱体宽度变量
box_width = 0.4

# 创建箱线图
plt.figure(figsize=(5, 6))
for idx, col in enumerate(df.columns):
    plt.boxplot(df[col], positions=[idx + 1], widths=box_width, patch_artist=True,
                boxprops=dict(facecolor=colors[idx], edgecolor='black', linewidth=1),
                medianprops=medianprops)

# 设置x轴标签，移除x轴刻度，调整y轴位置，并设置y轴标签
plt.xticks(range(1, len(df.columns) + 1), df.columns, rotation=45, fontsize=20, verticalalignment='top')
plt.tick_params(axis='x', length=0, pad=-1)  # 设置x轴标题与x轴之间的距离
plt.tick_params(axis='y', direction='out', length=6, labelsize=18)
plt.ylabel('Fct(s)', fontsize=25)

# 在整个图形周围添加边框
plt.gca().add_patch(plt.Rectangle((-0.5, plt.gca().get_ylim()[0]), len(df.columns) + 1,
                                  plt.gca().get_ylim()[1] - plt.gca().get_ylim()[0],
                                  fill=None, edgecolor='black', linewidth=1.2))

# 显示没有网格线和标题的图形
plt.grid(False)
plt.tight_layout()

plt.savefig('allreduce.png', dpi=1000)
plt.show()
