# %% [markdown]
# <a href="https://colab.research.google.com/github/li199959/one/blob/main/zhexian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the files
bc_default = pd.read_csv('bc_default.csv')
ag_tune = pd.read_csv('ag_tune.csv')
a2a_tune = pd.read_csv('a2a_tune.csv')
ag_default = pd.read_csv('ag_deault.csv')  # Adjust the filename if necessary
a2a_default = pd.read_csv('a2a_default.csv')
ar_default = pd.read_csv('ar_default.csv')
bc_tune = pd.read_csv('bc_tune.csv')
ar_tune = pd.read_csv('ar_tune.csv')

# Setting up the color scheme for each pair
colors = {
    'bc_default': 'blue',
    'bc_tune': 'lightblue',
    'ag_default': 'green',
    'ag_tune': 'lightgreen',
    'a2a_default': 'red',
    'a2a_tune': 'pink',
    'ar_default': 'purple',
    'ar_tune': 'violet'
}

# # Setting up figure and axes for the plots
# fig, axs = plt.subplots(4, 1, figsize=(10, 20))

# # Adjusting each plot with its own x_data based on the length of each dataset
# axs[0].plot(np.arange(len(bc_default)), bc_default, label='bc_default', color=colors['bc_default'])
# axs[0].plot(np.arange(len(bc_tune)), bc_tune, label='bc_tune', color=colors['bc_tune'])
# axs[0].set_title('BC Default vs BC Tune')
# axs[0].legend()

# # axs[1].plot(np.arange(len(ag_default)), ag_default, label='ag_default', color=colors['ag_default'])
# # axs[1].plot(np.arange(len(ag_tune)), ag_tune, label='ag_tune', color=colors['ag_tune'])
# # axs[1].set_title('AG Default vs AG Tune')
# # axs[1].legend()

# # axs[2].plot(np.arange(len(a2a_default)), a2a_default, label='a2a_default', color=colors['a2a_default'])
# # axs[2].plot(np.arange(len(a2a_tune)), a2a_tune, label='a2a_tune', color=colors['a2a_tune'])
# # axs[2].set_title('A2A Default vs A2A Tune')
# # axs[2].legend()

# # axs[3].plot(np.arange(len(ar_default)), ar_default, label='ar_default', color=colors['ar_default'])
# # axs[3].plot(np.arange(len(ar_tune)), ar_tune, label='ar_tune', color=colors['ar_tune'])
# # axs[3].set_title('AR Default vs AR Tune')
# # axs[3].legend()

# plt.tight_layout()
# plt.show()
# Function to plot each comparison
def plot_comparison(data1, data2, label1, label2, title):
    plt.figure(figsize=(10, 5))
    plt.plot(np.arange(len(data1)), data1, label=label1, color=colors[label1])
    plt.plot(np.arange(len(data2)), data2, label=label2, color=colors[label2])
    plt.title(title)
    plt.legend()
    plt.show()

# Plot each comparison
plot_comparison(bc_default, bc_tune, 'bc_default', 'bc_tune', 'BC Default vs BC Tune')
plot_comparison(ag_default, ag_tune, 'ag_default', 'ag_tune', 'AG Default vs AG Tune')
plot_comparison(a2a_default, a2a_tune, 'a2a_default', 'a2a_tune', 'A2A Default vs A2A Tune')
plot_comparison(ar_default, ar_tune, 'ar_default', 'ar_tune', 'AR Default vs AR Tune')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the files
bc_default = pd.read_csv('bc_default.csv')
ag_tune = pd.read_csv('ag_tune.csv')
a2a_tune = pd.read_csv('a2a_tune.csv')
ag_default = pd.read_csv('ag_deault.csv')  # Adjust the filename if necessary
a2a_default = pd.read_csv('a2a_default.csv')
ar_default = pd.read_csv('ar_default.csv')
bc_tune = pd.read_csv('bc_tune.csv')
ar_tune = pd.read_csv('ar_tune.csv')

# Setting up the color scheme for each pair
colors = {
    'bc_default': 'blue',
    'bc_tune': 'lightblue',
    'ag_default': 'green',
    'ag_tune': 'lightgreen',
    'a2a_default': 'red',
    'a2a_tune': 'pink',
    'ar_default': 'purple',
    'ar_tune': 'violet'
}

def plot_comparison(data1, data2, label1, label2, title):
    plt.figure(figsize=(10, 5))
    plt.plot(np.arange(len(data1)), data1, label=label1, color=colors[label1])
    plt.plot(np.arange(len(data2)), data2, label=label2, color=colors[label2])
    plt.title(title)
    plt.legend()
    plt.show()

# Plot each comparison
plot_comparison(bc_default, bc_tune, 'bc_default', 'bc_tune', 'BC Default vs BC Tune')
plot_comparison(ag_default, ag_tune, 'ag_default', 'ag_tune', 'AG Default vs AG Tune')
plot_comparison(a2a_default, a2a_tune, 'a2a_default', 'a2a_tune', 'A2A Default vs A2A Tune')
plot_comparison(ar_default, ar_tune, 'ar_default', 'ar_tune', 'AR Default vs AR Tune')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the files
bc_default = pd.read_csv('bc_default.csv')
ag_tune = pd.read_csv('ag_tune.csv')
a2a_tune = pd.read_csv('a2a_tune.csv')
ag_default = pd.read_csv('ag_deault.csv')  # Adjust the filename if necessary
a2a_default = pd.read_csv('a2a_default.csv')
ar_default = pd.read_csv('ar_default.csv')
bc_tune = pd.read_csv('bc_tune.csv')
ar_tune = pd.read_csv('ar_tune.csv')

# Setting up the color scheme for each pair
colors = {
    'bc_default': 'blue',
    'bc_tune': 'lightblue',
    'ag_default': 'green',
    'ag_tune': 'lightgreen',
    'a2a_default': 'red',
    'a2a_tune': 'pink',
    'ar_default': 'purple',
    'ar_tune': 'violet'
}

def plot_comparison(data1, data2, label1, label2, title, ylim=None):
    plt.figure(figsize=(5, 2.5))
    plt.plot(np.arange(len(data1)), data1, label=label1, color=colors[label1])
    plt.plot(np.arange(len(data2)), data2, label=label2, color=colors[label2])
    plt.title(title)
    plt.legend()
    if ylim is not None:
        plt.ylim(ylim)
    plt.show()

# Plot each comparison
plot_comparison(bc_default, bc_tune, 'bc_default', 'bc_tune', 'BC Default vs BC Tune', ylim=(20, 50))
plot_comparison(ag_default, ag_tune, 'ag_default', 'ag_tune', 'AG Default vs AG Tune', ylim=(20, 50))
plot_comparison(a2a_default, a2a_tune, 'a2a_default', 'a2a_tune', 'A2A Default vs A2A Tune', ylim=(20, 50))
plot_comparison(ar_default, ar_tune, 'ar_default', 'ar_tune', 'AR Default vs AR Tune', ylim=(20, 50))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the files
bc_default = pd.read_csv('bc_default.csv')
ag_tune = pd.read_csv('ag_tune.csv')
a2a_tune = pd.read_csv('a2a_tune.csv')
ag_default = pd.read_csv('ag_deault.csv')  # Adjust the filename if necessary
a2a_default = pd.read_csv('a2a_default.csv')
ar_default = pd.read_csv('ar_default.csv')
bc_tune = pd.read_csv('bc_tune.csv')
ar_tune = pd.read_csv('ar_tune.csv')

# Setting up the color scheme for each pair
colors = {
    'bc_default': 'blue',
    'bc_tune': 'lightblue',
    'ag_default': 'green',
    'ag_tune': 'lightgreen',
    'a2a_default': 'red',
    'a2a_tune': 'pink',
    'ar_default': 'purple',
    'ar_tune': 'violet'
}

def plot_comparison(data1, data2, label1, label2, title, ylim=None):
    plt.figure(figsize=(10, 5))
    plt.plot(np.arange(len(data1)), data1, label=label1, color=colors[label1])
    plt.plot(np.arange(len(data2)), data2, label=label2, color=colors[label2])
    plt.title(title)
    if ylim is not None:
        plt.ylim(ylim)
    plt.legend(loc='lower left')
    plt.show()

# Plot each comparison
plot_comparison(bc_default, bc_tune, 'bc_default', 'bc_tune', 'BC Default vs BC Tune', ylim=(0, 100))
plot_comparison(ag_default, ag_tune, 'ag_default', 'ag_tune', 'AG Default vs AG Tune', ylim=(0, 100))
plot_comparison(a2a_default, a2a_tune, 'a2a_default', 'a2a_tune', 'A2A Default vs A2A Tune', ylim=(0, 100))
plot_comparison(ar_default, ar_tune, 'ar_default', 'ar_tune', 'AR Default vs AR Tune', ylim=(0, 100))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the files
bc_default = pd.read_csv('bc_default.csv')
ag_tune = pd.read_csv('ag_tune.csv')
a2a_tune = pd.read_csv('a2a_tune.csv')
ag_default = pd.read_csv('ag_deault.csv')  # Adjust the filename if necessary
a2a_default = pd.read_csv('a2a_default.csv')
ar_default = pd.read_csv('ar_default.csv')
bc_tune = pd.read_csv('bc_tune.csv')
ar_tune = pd.read_csv('ar_tune.csv')

# Setting up the color scheme for each pair
colors = {
    'bc_default': 'blue',
    'bc_tune': 'lightblue',
    'ag_default': 'green',
    'ag_tune': 'lightgreen',
    'a2a_default': 'red',
    'a2a_tune': 'pink',
    'ar_default': 'purple',
    'ar_tune': 'violet'
}

def plot_comparison(data1, data2, label1, label2, title, ylim=None):
    plt.figure(figsize=(5, 2.5))
    plt.plot(np.arange(len(data1)), data1, label=label1, color=colors[label1])
    plt.plot(np.arange(len(data2)), data2, label=label2, color=colors[label2])
    plt.title(title)
    if ylim is not None:
        plt.ylim(ylim)
    plt.legend(loc='lower left', fontsize='small', frameon=True, fancybox=True,  edgecolor='black')
        # plt.legend(loc='lower left', fontsize='medium', frameon=True, fancybox=True, facecolor='lightgrey', edgecolor='black')

    plt.show()

# Plot each comparison
plot_comparison(bc_default, bc_tune, 'bc_default', 'bc_tune', 'BC Default vs BC Tune', ylim=(0, 100))
plot_comparison(ag_default, ag_tune, 'ag_default', 'ag_tune', 'AG Default vs AG Tune', ylim=(0, 100))
plot_comparison(a2a_default, a2a_tune, 'a2a_default', 'a2a_tune', 'A2A Default vs A2A Tune', ylim=(0, 100))
plot_comparison(ar_default, ar_tune, 'ar_default', 'ar_tune', 'AR Default vs AR Tune', ylim=(0, 100))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-a8e83188d3f3> in <cell line: 45>()
#      43 # plot_comparison(ar_default, ar_tune, 'ar_default', 'ar_tune', 'AR Default vs AR Tune', ylim=(0, 100))
#      44 # Plot each comparison
# ---> 45 plot_comparison(bc_default, bc_tune, 'bc_default', 'bc_tune', 'BC Default vs BC Tune', ylim=(0, 100), dpi=150)
#      46 plot_comparison(ag_default, ag_tune, 'ag_default', 'ag_tune', 'AG Default vs AG Tune', ylim=(0, 100), dpi=150)
#      47 plot_comparison(a2a_default, a2a_tune, 'a2a_default', 'a2a_tune', 'A2A Default vs A2A Tune', ylim=(0, 100), dpi=150)
#
# TypeError: plot_comparison() got an unexpected keyword argument 'dpi'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the files
bc_default = pd.read_csv('bc_default.csv')
ag_tune = pd.read_csv('ag_tune.csv')
a2a_tune = pd.read_csv('a2a_tune.csv')
ag_default = pd.read_csv('ag_deault.csv')  # Adjust the filename if necessary
a2a_default = pd.read_csv('a2a_default.csv')
ar_default = pd.read_csv('ar_default.csv')
bc_tune = pd.read_csv('bc_tune.csv')
ar_tune = pd.read_csv('ar_tune.csv')

# Setting up the color scheme for each pair
colors = {
    'bc_default': 'blue',
    'bc_tune': 'lightblue',
    'ag_default': 'green',
    'ag_tune': 'lightgreen',
    'a2a_default': 'red',
    'a2a_tune': 'pink',
    'ar_default': 'purple',
    'ar_tune': 'violet'
}

def plot_comparison(data1, data2, label1, label2, title, ylim=None, dpi=100):
    plt.figure(figsize=(5, 2.5), dpi=dpi)
    plt.plot(np.arange(len(data1)), data1, label=label1, color=colors[label1])
    plt.plot(np.arange(len(data2)), data2, label=label2, color=colors[label2])
    plt.title(title)
    if ylim is not None:
        plt.ylim(ylim)
    plt.legend(loc='lower left')
    plt.show()

# Plot each comparison
plot_comparison(bc_default, bc_tune, 'bc_default', 'bc_tune', 'BC Default vs BC Tune', ylim=(0, 100), dpi=300)
plot_comparison(ag_default, ag_tune, 'ag_default', 'ag_tune', 'AG Default vs AG Tune', ylim=(0, 100), dpi=300)
plot_comparison(a2a_default, a2a_tune, 'a2a_default', 'a2a_tune', 'A2A Default vs A2A Tune', ylim=(0, 100), dpi=300)
plot_comparison(ar_default, ar_tune, 'ar_default', 'ar_tune', 'AR Default vs AR Tune', ylim=(0, 100), dpi=300)
